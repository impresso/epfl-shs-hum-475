# %% [markdown]
# ## Small example using a french sentiment analysis model
# https://github.com/TheophileBlard/french-sentiment-analysis-with-bert
#
# **Attention**: The model was trained on clean text and on movie reviews (allocine). Usually sentiment analysis does not reach satisfying performances (e.g. modeling negation and sarcasm is difficult) and one needs to be *very* cautious w.r.t how to train and apply a model, and interpret the results.
#
# Voir aussi les travaux des étudiants sur l'OPEP: https://github.com/RPetitpierre/letemps_archive_opep/blob/master/Sentiment_%26_TTK.ipynb
# basés sur TextBlob: https://textblob.readthedocs.io/en/dev/

# %%
import tensorflow as tf
assert tf.__version__ >= "2.0"

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("tblard/tf-allocine", use_fast=True)
model = TFAutoModelForSequenceClassification.from_pretrained("tblard/tf-allocine")

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/210 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/425M [00:00<?, ?B/s]
# 2022-03-16 15:01:29.699209: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All model checkpoint layers were used when initializing TFCamembertForSequenceClassification.
#
# All the layers of TFCamembertForSequenceClassification were initialized from the model checkpoint at tblard/tf-allocine.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFCamembertForSequenceClassification for predictions without further training.

# %%
import pandas as pd
import os

# %%
collection = "../data/fc7ae723-sample200.csv"
df = pd.read_csv(collection, sep=';', encoding='utf-8')

# %%
df.head()
# Out:
#                       uid  type language               title  size country  \
# 0  EXP-1907-11-14-a-i0043   NaN       fr  LES DEUX NOBLESSES   741      CH
# 1  EXP-1912-02-09-a-i0071   NaN       fr           POLITIQUE   185      CH
# 2  EXP-1913-02-11-a-i0039   NaN       fr           POLITIQUE   460      CH
# 3  EXP-1913-10-21-a-i0061   NaN       fr           POLITIQUE   527      CH
# 4  EXP-1913-12-22-a-i0121   NaN       fr           POLITIQUE   358      CH
#
#   newspaper             issue  pages  nb_pages  ...  is_on_front  \
# 0       EXP  EXP-1907-11-14-a      3         1  ...        False
# 1       EXP  EXP-1912-02-09-a      6         1  ...        False
# 2       EXP  EXP-1913-02-11-a      3         1  ...        False
# 3       EXP  EXP-1913-10-21-a      4         1  ...        False
# 4       EXP  EXP-1913-12-22-a      8         1  ...        False
#
#                    date                                  persons_mentioned  \
# 0  1907-11-14T00:00:00Z  roi Edouard Vll|comédien John Hare|baryton Cha...
# 1  1912-02-09T00:00:00Z  M. Churchill|M. Winston Churchill|M. Winston C...
# 2  1913-02-11T00:00:00Z                                  Winston Churchill
# 3  1913-10-21T00:00:00Z  M. Winston|M. Churchill|Lionel Garden, ministr...
# 4  1913-12-22T00:00:00Z       M. Churchill M. Winston|M. Tedesco, ministre
#
#                                  locations_mentioned  \
# 0  Angleterre|Churchill|Gladstone|Victoria|Anglet...
# 1  Irlande|Belfast|Churchill|Irlande|Grande-Breta...
# 2  ALLEMAGNE|Allemagne|Allemagne|Churchill|Anglet...
# 3  ROYAUME-UNI|Churchill|Manchester|Allemagne|Ang...
# 4    Churchill|Paris|Italie|Libye|Italie|Addis-Abeba
#
#                                              content access_right  \
# 0  LES DEUX NOBLESSES On lit dans le « Temps » : ...  OpenPrivate
# 1  POLITIQUE M. Churchill en Irlande M. Winston C...  OpenPrivate
# 2  POLITIQUE -f ~ " _. ALLEMAGNE.. " jW _» Tandis...  OpenPrivate
# 3  POLITIQUE ROYAUME-UNI M. Winston. Churchill a ...  OpenPrivate
# 4  POLITIQUE Finances françaises M. Cailiaux, min...  OpenPrivate
#
#   content_provider is_content_available          collections  \
# 0              SNL                 True  local-bewa-JplM5OCI
# 1              SNL                 True                  NaN
# 2              SNL                 True                  NaN
# 3              SNL                 True                  NaN
# 4              SNL                 True                  NaN
#
#    [total:2493,available:2500]
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 22 columns]

# %%
print(nlp("Alad'2 est clairement le meilleur film de l'année 2018.")) # POSITIVE
print(nlp("Juste whoaaahouuu !")) # POSITIVE
print(nlp("NUL...A...CHIER ! FIN DE TRANSMISSION.")) # NEGATIVE
print(nlp("Je m'attendais à mieux de la part de Franck Dubosc !")) # NEGATIVE
# Out:
# [{'label': 'POSITIVE', 'score': 0.9657254219055176}]
# [{'label': 'POSITIVE', 'score': 0.9862489104270935}]
# [{'label': 'NEGATIVE', 'score': 0.9974060654640198}]
# [{'label': 'NEGATIVE', 'score': 0.9956079125404358}]

# %%
for row in df.itertuples():
    if row.title is not None and isinstance(row.title, str):
        print(row.title, nlp(row.title))
# Out:
# LES DEUX NOBLESSES [{'label': 'NEGATIVE', 'score': 0.7967727184295654}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# L'Amirauté anglaise [{'label': 'NEGATIVE', 'score': 0.5071859359741211}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# HPOLITIQUE [{'label': 'POSITIVE', 'score': 0.854310154914856}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# I_ettre de -Londres [{'label': 'POSITIVE', 'score': 0.5437754392623901}]
# LIBRAIRIE [{'label': 'NEGATIVE', 'score': 0.5715366005897522}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# L'amortissement des dettes de guerre [{'label': 'NEGATIVE', 'score': 0.6208540201187134}]
# POLITIQUE [{'label': 'NEGATIVE', 'score': 0.6124337911605835}]
# L'entrevue Poincaré, Churchill et Parker Gilbert [{'label': 'POSITIVE', 'score': 0.8359973430633545}]
# liés entretiens de Paris [{'label': 'POSITIVE', 'score': 0.5828598141670227}]
# Revue de la presèe [{'label': 'NEGATIVE', 'score': 0.6592487692832947}]
# COMMENT CHAQUE CANDIDAT SE DOIT DE RENDRE VISITE... A CHACUN DE SES EL[...] [{'label': 'NEGATIVE', 'score': 0.5298917889595032}]
# La coalition nationale restera au gouvernement en Grande-Bretagne [{'label': 'POSITIVE', 'score': 0.5144082903862}]
# Sarah Churchill la fille de l'homme politique anglais épouse un acteur [{'label': 'NEGATIVE', 'score': 0.5740485191345215}]
# Les canons de Franco installés aux environs de Gibraltar [{'label': 'NEGATIVE', 'score': 0.6071244478225708}]
# Une crise ministérielle se produirait prochainement en Grande-Bretagne [{'label': 'POSITIVE', 'score': 0.528600811958313}]
# M. Conrad Henlein s'est entretenu avec de nombreuses personnalités pol[...] [{'label': 'NEGATIVE', 'score': 0.5408080816268921}]
# Après le voyage de M. Henlein en Angleterre [{'label': 'NEGATIVE', 'score': 0.7991732954978943}]
# L'efficacité du blocus économique dirigé contre le troisième Reich [{'label': 'POSITIVE', 'score': 0.6334989666938782}]
# Paroles déplacées [{'label': 'NEGATIVE', 'score': 0.9554530382156372}]
# Et les Anglais commémorent 1 année bissextile [{'label': 'NEGATIVE', 'score': 0.5138616561889648}]
# Le cabinet Churchill est constitué [{'label': 'POSITIVE', 'score': 0.6307271122932434}]
# L&lt;£t guerre sur le front occidental [{'label': 'POSITIVE', 'score': 0.6601691246032715}]
# Rupture de l'entente anglo -française [{'label': 'NEGATIVE', 'score': 0.5643470287322998}]
# La France vaincue envisage sa reconstruction [{'label': 'NEGATIVE', 'score': 0.6657510995864868}]
# Les relations anglo- nipponnes [{'label': 'POSITIVE', 'score': 0.5022825002670288}]
# L'entrevue Churchill-Roosevelt a vraisemblablement en lieu [{'label': 'NEGATIVE', 'score': 0.524569034576416}]
# M.Winston Churchill passe en revue les événements politiques et milita[...] [{'label': 'POSITIVE', 'score': 0.6544893980026245}]
# Le président Roosevelt fait le point des travaux accomplis en une sema[...] [{'label': 'POSITIVE', 'score': 0.5018050074577332}]
# M. Churchill remanie son cabinet de guerre [{'label': 'NEGATIVE', 'score': 0.7431185841560364}]
# Londres commente les discours Churchill et Roosevelt [{'label': 'POSITIVE', 'score': 0.6794335842132568}]
# L'exposé de M. Winston Churchill sur la situation internationale [{'label': 'POSITIVE', 'score': 0.7098734974861145}]
# UNE DéCLARATION AUX COMMUNES DE M. WINSTON CHURCHILL SUR LES EVéNEMENT[...] [{'label': 'NEGATIVE', 'score': 0.655052661895752}]
# M. WINSTON CHURCHILL ARRIVE AU CANADA [{'label': 'NEGATIVE', 'score': 0.6278533339500427}]
# M.WINSTON CHURCHILL passe en revue les événements politiques et milita[...] [{'label': 'POSITIVE', 'score': 0.5937100052833557}]
# N. Churchill à la Maison-Blanche [{'label': 'POSITIVE', 'score': 0.6826348304748535}]
# H. Churchill s'est remis an travail [{'label': 'POSITIVE', 'score': 0.6006671190261841}]
# MADAME CHURCHILL [{'label': 'POSITIVE', 'score': 0.5231363773345947}]
# M. WINSTON CHURCHILL EN VISITE OFFICIELLE DANS LA CAPITALE FRANÇAISE [{'label': 'POSITIVE', 'score': 0.5535953640937805}]
# LA VISITE A PARIS DE M. WINSTON CHURCHILL [{'label': 'POSITIVE', 'score': 0.533946692943573}]
# LA CONFÉRENCE TRIPARTITE A COMMENCÉ SES TRAVAUX [{'label': 'NEGATIVE', 'score': 0.7469148635864258}]
# C'est aujourd'hui que l'Angleterre renouvelle son parlement [{'label': 'POSITIVE', 'score': 0.7289988398551941}]
# Grande victoire des travaillistes qui emportent la majorité des sièges [{'label': 'POSITIVE', 'score': 0.9401562213897705}]
# - , ¦ . LegénéralWeygandexposelesraisons pourlesquellesilaconclu(armis[...] [{'label': 'POSITIVE', 'score': 0.6276861429214478}]
# Ce que fut l'entrevue d'octobre 1940 entre MM. Churchill et Rougier [{'label': 'POSITIVE', 'score': 0.585172712802887}]
# LA VISITE TRIOMPHALE DE M. WINSTON CHURCHILL DANS LA CAPITALE BELGE [{'label': 'POSITIVE', 'score': 0.5752810835838318}]
# M. Churchill fait le procès de la politique travailliste [{'label': 'NEGATIVE', 'score': 0.5950274467468262}]
# M. Churchill se prononce en laveur d'une collaboration étroite entre l[...] [{'label': 'NEGATIVE', 'score': 0.5951313972473145}]
# Staline attaque M. Winston Churchill [{'label': 'POSITIVE', 'score': 0.603289008140564}]
# Un débat aux Communes sur le retrait des troupes anglaises d' Egypte [{'label': 'NEGATIVE', 'score': 0.5024132132530212}]
# M. WINSTON CHURCHILL A METZ [{'label': 'NEGATIVE', 'score': 0.6531437039375305}]
# HOMMAGE A M. WINSTON CHURCHILL [{'label': 'POSITIVE', 'score': 0.6254447102546692}]
# M. Churchill apparaît souriant à sa descente d'avion, à Cointrin [{'label': 'POSITIVE', 'score': 0.7126328349113464}]
# Mlle Churchill au concours hippique de Genève [{'label': 'POSITIVE', 'score': 0.5500398278236389}]
# A L'ÉCOLE DE CHURCHILL [{'label': 'NEGATIVE', 'score': 0.5682525038719177}]
# Toute la population lausannoise a acclamé M. Churchill [{'label': 'POSITIVE', 'score': 0.887418270111084}]
# Toute la population lausannoise a acclamé M. Churchill [{'label': 'POSITIVE', 'score': 0.887418270111084}]
# M. Winston Churchill a pris congé hier matin de la population de Bursi[...] [{'label': 'NEGATIVE', 'score': 0.5905613303184509}]
# Berne acclame M. Winston Churchill [{'label': 'POSITIVE', 'score': 0.641314685344696}]
# La population de Zurich reçoit triomphalement M. Churchill [{'label': 'POSITIVE', 'score': 0.8162631988525391}]
# M. WINSTON CHURCHILL A ZURICH [{'label': 'POSITIVE', 'score': 0.5041713714599609}]
# M. WINSTON CHURCHILL A QUITTÉ LA SUISSE HIER MATIN [{'label': 'NEGATIVE', 'score': 0.5749337077140808}]
# Le parti travailliste a affaibli l'influence britannique à l'étranger [{'label': 'NEGATIVE', 'score': 0.7082523703575134}]
# Fchosdujvlonde ^^^A ••&lt; o II&gt; MM IIIIIIII. IIMII tiiiiiintiiiKui[...] [{'label': 'POSITIVE', 'score': 0.7907748818397522}]
# le monument Churchill près de Douvres sera-t-il érigé? [{'label': 'POSITIVE', 'score': 0.6600531935691833}]
# M. WINSTON CHURCHILL DICTE SES MÉMOIRES... [{'label': 'NEGATIVE', 'score': 0.5319567322731018}]
# tcfios du Monde [{'label': 'POSITIVE', 'score': 0.667458176612854}]
# M. Churchill est arrivé hier à Paris [{'label': 'POSITIVE', 'score': 0.6410850286483765}]
# M. Churchill a reçu du président Ramadier la médaille militaire . [{'label': 'POSITIVE', 'score': 0.6290661096572876}]
# Le parti conservateur anglais va tenir la semaine prochaine un importa[...] [{'label': 'NEGATIVE', 'score': 0.7460981011390686}]
# Le gouvernemenl Attlee veut éviter de nouvelles élections générales [{'label': 'NEGATIVE', 'score': 0.6514530181884766}]
# I„i«11I»I»l, _________ J ________- .I__II_._I9._.._______...____, [{'label': 'POSITIVE', 'score': 0.7294413447380066}]
# L'art d'être grand-père [{'label': 'POSITIVE', 'score': 0.5553494691848755}]
# GENS ET CHOSES DONT ON PARLE [{'label': 'POSITIVE', 'score': 0.6120675802230835}]
# K£s [{'label': 'POSITIVE', 'score': 0.7462961077690125}]
# Les assises de la Haye [{'label': 'POSITIVE', 'score': 0.6324542760848999}]
# M. Churchill arrive en France où il passera ses vacances [{'label': 'POSITIVE', 'score': 0.5950168371200562}]
# Pendant les vacances qu'il passe à Aix-en-Provence, Churchill juché su[...] [{'label': 'POSITIVE', 'score': 0.61796635389328}]
# Discours de MM. Churchill et Eden en faveur du renforcement de l'armée[...] [{'label': 'POSITIVE', 'score': 0.6232005953788757}]
# £eséchosduiTfSHTpra „ l.il.ili.i il..- ,; ' !..!hfl I II....,.,,. [{'label': 'POSITIVE', 'score': 0.8374055624008179}]
# Petits échos [{'label': 'POSITIVE', 'score': 0.5559137463569641}]
# L'Assemblée européenne de Strasbourg [{'label': 'NEGATIVE', 'score': 0.6337956190109253}]
# Motion de M. Churchill à Strasbourg [{'label': 'POSITIVE', 'score': 0.6454455256462097}]
# «Le premier pas est franchi déclare M. Winston Churchill [{'label': 'POSITIVE', 'score': 0.7240540385246277}]
# Les manipulations monétaires dans le monde et leurs répercussions [{'label': 'POSITIVE', 'score': 0.8299160599708557}]
# M. Winston Churchill renouvelle su proposition de rencontrer Staline [{'label': 'POSITIVE', 'score': 0.6895161867141724}]
# Le port « Churchill » d'Arromanches sera-t-il vendu à l'encan ? [{'label': 'POSITIVE', 'score': 0.5350707173347473}]
# Nouvelle dérobade de M. Attlee ou sujet du plun Schuman [{'label': 'NEGATIVE', 'score': 0.5647937655448914}]
# Le président Truman donne l'ordre à l'aviation et à la flotte américai[...] [{'label': 'POSITIVE', 'score': 0.6488126516342163}]
# MM. Attlee et Churchill approuvent tour à tour l'intervention américai[...] [{'label': 'POSITIVE', 'score': 0.501787543296814}]
# M. WINSTON CHURCHILL DE PASSAGE A PARIS [{'label': 'NEGATIVE', 'score': 0.5310817360877991}]
# M. Churchill accuse les travaillistes d'avoir ruiné Se prestige de son[...] [{'label': 'POSITIVE', 'score': 0.5883150696754456}]
# Les Anglais votent aujourd'hui [{'label': 'NEGATIVE', 'score': 0.5359029173851013}]
# LES PREMIERS RÉSULTATS DES ÉLECTIONS ANGLAISES [{'label': 'NEGATIVE', 'score': 0.7375432848930359}]
# Victoire des cosa^-rvateiirs mm élections brîtcuniiques [{'label': 'POSITIVE', 'score': 0.5533802509307861}]
# LA VICTOIRE DES CONSERVATEURS [{'label': 'NEGATIVE', 'score': 0.5274008512496948}]
# M. Churchill o complété la liste de ses collaborateurs [{'label': 'NEGATIVE', 'score': 0.5836581587791443}]
# Churchill et Truman se rencontreront à Washington [{'label': 'POSITIVE', 'score': 0.6902073621749878}]
# M. Churchill partira à la lin de décembre pour les Etats-Unis [{'label': 'POSITIVE', 'score': 0.5355978608131409}]
# IJH JII JHQ I m ou 1 ^ #1 'I u» 3 wl l_MJnh.MidlnAtnllamiil ,Hnaie [{'label': 'POSITIVE', 'score': 0.7550249695777893}]
# £eséchosduEW_WÏ liilhilu liiMxrifliihisiHiiiiifflliinMih. [{'label': 'POSITIVE', 'score': 0.77620530128479}]
# MM. Churchill et Eden sont arrivés hier à Paris pour discuter des gran[...] [{'label': 'NEGATIVE', 'score': 0.5371706485748291}]
# M. Churchill à Paris [{'label': 'POSITIVE', 'score': 0.5817245244979858}]
# MM. Churchill et Eden sont rentrés à Londres [{'label': 'NEGATIVE', 'score': 0.53284752368927}]
# Le départ de M. Churchill ajourné de 24 heures [{'label': 'NEGATIVE', 'score': 0.8045854568481445}]
# NI Churchill est arrivé à Washington [{'label': 'NEGATIVE', 'score': 0.7188266515731812}]
# L'avenir du pays est incertain et gris comme le ciel, cet été... orage[...] [{'label': 'NEGATIVE', 'score': 0.6066993474960327}]
# M. Churchill aurait élaboré un plan révolutionnaire de défense et de r[...] [{'label': 'POSITIVE', 'score': 0.5420435667037964}]
# M.Churchill serendra àWashington le mois prochain [{'label': 'POSITIVE', 'score': 0.677493691444397}]
# M.Winston Churchill arrivé hier à New-York [{'label': 'POSITIVE', 'score': 0.6649537086486816}]
# Des sénateurs américains mécontents des déclarations de M. Churchill s[...] [{'label': 'NEGATIVE', 'score': 0.6521949768066406}]
# Les entretiens franco-hriianniques de Londres ont pris fin [{'label': 'NEGATIVE', 'score': 0.747118353843689}]
# La dernière journée du séjour à Londres du maréchal Tito [{'label': 'NEGATIVE', 'score': 0.5979705452919006}]
# Le discours de sir Winston Churchill [{'label': 'POSITIVE', 'score': 0.6207767128944397}]
# Le discours Churchill accueilli avec satisfaction à Moscou [{'label': 'POSITIVE', 'score': 0.8414915800094604}]
# Les conseils de sir Winston Churchill sur la conduite de la guerre d'I[...] [{'label': 'POSITIVE', 'score': 0.6573942303657532}]
# APRÈS LE DISCOURS DE SIR WINSTON CHURCHILL [{'label': 'POSITIVE', 'score': 0.5378161072731018}]
# jfiaass [{'label': 'POSITIVE', 'score': 0.7373688220977783}]
# Churchill soigne sa «dépression» [{'label': 'NEGATIVE', 'score': 0.5404096841812134}]
# La maladie de sir Winston Churchill annonce des changements dans la co[...] [{'label': 'NEGATIVE', 'score': 0.5358468890190125}]
# COMMENT LA GRANDE-BRETAGNE A PASSÉ SES VACANCES [{'label': 'NEGATIVE', 'score': 0.879126250743866}]
# Le programme de Churchill reste une énigme [{'label': 'NEGATIVE', 'score': 0.8091657161712646}]
# Du congrès des Trade-Unions à celui du Labour party [{'label': 'POSITIVE', 'score': 0.6350722312927246}]
# SIR WINSTON CHURCHILL PRIX NOBEL DE LITTÉRATURE [{'label': 'POSITIVE', 'score': 0.5919660925865173}]
# La conférence des Bermudes redevient d'actualité [{'label': 'POSITIVE', 'score': 0.7162654399871826}]
# Sir Winston Churchill a fêté hier son 79me anniversaire [{'label': 'POSITIVE', 'score': 0.7429384589195251}]
# La conférence des Bermudes [{'label': 'POSITIVE', 'score': 0.5785365104675293}]
# LeprésidentEisenhower estarrivéhierauxBermudes * [{'label': 'POSITIVE', 'score': 0.6124386787414551}]
# Les résultats de la conférence des Bermudes [{'label': 'POSITIVE', 'score': 0.58314049243927}]
# Le roi de Suède a remis hier les prix Nobel aux lauréats de 1953 [{'label': 'POSITIVE', 'score': 0.7261176705360413}]
# Sir Winston Churchill fait le point aux Communes de la situation inter[...] [{'label': 'POSITIVE', 'score': 0.5976128578186035}]
# Les essais de la bombe «H» augmentent les chances de la paix mondiale [{'label': 'POSITIVE', 'score': 0.6801560521125793}]
# Autour du monde en quelques lignes [{'label': 'POSITIVE', 'score': 0.5910822153091431}]
# Vers une rencontre Eisenhower-Ghurchili-Malenkov ? [{'label': 'POSITIVE', 'score': 0.7267642617225647}]
# « Il est nécessaire que les Etats-Unis trouvent un moyen de vivre en c[...] [{'label': 'POSITIVE', 'score': 0.5188230872154236}]
# MM. Churchill et Foster Dulles approuvent le chancelier Adenauer [{'label': 'POSITIVE', 'score': 0.678144097328186}]
# Trois événements consolident la position parlementaire de M. Mendès-Fr[...] [{'label': 'POSITIVE', 'score': 0.5224499702453613}]
# M. Churchill se félicite des accords de Londres [{'label': 'POSITIVE', 'score': 0.6967619061470032}]
# La Suisse a fêté le général Guisan [{'label': 'POSITIVE', 'score': 0.6599485874176025}]
# Monde [{'label': 'POSITIVE', 'score': 0.556753396987915}]
# Churchill descendrait de Gharlemagne ! [{'label': 'NEGATIVE', 'score': 0.5174422264099121}]
# Sir Winston Churchill fête aujourd'hui son quatre-vingtième anniversai[...] [{'label': 'POSITIVE', 'score': 0.693416178226471}]
# Dispute au sujet de l'île de Chypre [{'label': 'NEGATIVE', 'score': 0.6991411447525024}]
# SPENCER TRACY, PHILOSOPHE Entre dieaux p... [{'label': 'NEGATIVE', 'score': 0.6312242746353149}]
# Margaret va s'envoler... [{'label': 'NEGATIVE', 'score': 0.8473408818244934}]
# MARGARET [{'label': 'NEGATIVE', 'score': 0.5781075954437256}]
# La motion travailliste blâmant M. Churchill de n'avoir pas convoqué un[...] [{'label': 'NEGATIVE', 'score': 0.7405238151550293}]
# Londres accueille les révélations «avec colère et consternation» [{'label': 'POSITIVE', 'score': 0.7098401188850403}]
# Lu démission de sir Winston serait rendue publique le 4 avril prochain [{'label': 'POSITIVE', 'score': 0.6843523383140564}]
# Paris et la conférence à 4 [{'label': 'POSITIVE', 'score': 0.5381264686584473}]
# Churchill a parlé de «son successeur» [{'label': 'POSITIVE', 'score': 0.5719628930091858}]
# SIsr Winston Churchill a remis hier sa démission à En reine Elizabeth [{'label': 'POSITIVE', 'score': 0.5247922539710999}]
# La France n'oubliera pas son fidèle ami [{'label': 'POSITIVE', 'score': 0.8279227018356323}]
# La démission de sir Winston [{'label': 'POSITIVE', 'score': 0.5818067193031311}]
# La leçon de Churchill [{'label': 'POSITIVE', 'score': 0.8126461505889893}]
# Sir Anthony premier ministre [{'label': 'POSITIVE', 'score': 0.6277035474777222}]
# M. Eden a remanié le cabinet britannique [{'label': 'POSITIVE', 'score': 0.5482110977172852}]
# RENDU A LA VIE CIVILE SIR WINSTON [{'label': 'POSITIVE', 'score': 0.6846411824226379}]
# L'ANGLETERRE SOUS LE TRIUMVIRAT [{'label': 'POSITIVE', 'score': 0.6013047099113464}]
# Le jeune lord travailliste Anthony Wedgwood Benn sera prisonnier des p[...] [{'label': 'NEGATIVE', 'score': 0.6271806955337524}]
# Les conséquences de la grève des chemins de fer en Grande-Bretagne [{'label': 'NEGATIVE', 'score': 0.5676062703132629}]
# L'ART DE DORMIR [{'label': 'POSITIVE', 'score': 0.5085703730583191}]
# Bas accusations fort contradictoires [{'label': 'NEGATIVE', 'score': 0.5651408433914185}]
# M. Churchill publie un gigantesque ouvrage: «L'histoire des peuples de[...] [{'label': 'POSITIVE', 'score': 0.7923856377601624}]
# PETITE CHRONIQUE DE LA T.V. [{'label': 'NEGATIVE', 'score': 0.7302514314651489}]
# Churchill subit une défaite, sur le plan théâtral [{'label': 'NEGATIVE', 'score': 0.9641076326370239}]
# La carrière de sir Anthony [{'label': 'POSITIVE', 'score': 0.7832753658294678}]
# CHURCHILL PRONONCE UN DISCOURS [{'label': 'NEGATIVE', 'score': 0.5694157481193542}]
# Churchill sort de son silence [{'label': 'POSITIVE', 'score': 0.724586546421051}]
# Churchill critique les Mations Unies [{'label': 'POSITIVE', 'score': 0.7335610389709473}]
# CHURCHILL A FÊTÉ SES 83 ANS !... [{'label': 'POSITIVE', 'score': 0.6138143539428711}]
# La Grande-Bretagne traverse une crise de régime [{'label': 'POSITIVE', 'score': 0.5712021589279175}]
# Churchill à de Gaulle [{'label': 'POSITIVE', 'score': 0.8033506274223328}]
# De Gaulle a remis à Churchill la croix de la Libération [{'label': 'POSITIVE', 'score': 0.7902392745018005}]
# LE GENERAL WEDEMEYER accuse Roosevelt... et Churchill [{'label': 'POSITIVE', 'score': 0.503318727016449}]
# L'appartement de Churchill cambriolé [{'label': 'NEGATIVE', 'score': 0.5072556734085083}]
# Churchill accepte une candidature [{'label': 'NEGATIVE', 'score': 0.5045620203018188}]
# Le scandale financier Jasper-Grunwald [{'label': 'POSITIVE', 'score': 0.5948928594589233}]
# Churchill : 85 ans [{'label': 'POSITIVE', 'score': 0.6912492513656616}]
# Le testament politique de Hitler [{'label': 'POSITIVE', 'score': 0.6670063734054565}]
# Une journée avec Churchill en 1940 [{'label': 'POSITIVE', 'score': 0.6213102340698242}]
# Discours au banquet officiel [{'label': 'POSITIVE', 'score': 0.5251661539077759}]
# De Gaulle à Londres [{'label': 'POSITIVE', 'score': 0.7593035697937012}]
# Churchill rendra visite à de Gaulle [{'label': 'POSITIVE', 'score': 0.7841776013374329}]
# CHURCHILL fait une chute [{'label': 'NEGATIVE', 'score': 0.9068226218223572}]
# PÊLE-MÊLE ?PÊLE-MÊLE [{'label': 'NEGATIVE', 'score': 0.871947169303894}]
# Churchill est toujours populaire [{'label': 'POSITIVE', 'score': 0.9116848111152649}]
# Churchill a fêfé hier son 86 me anniversaire [{'label': 'POSITIVE', 'score': 0.6471229195594788}]
# Pêle-mêle • Pêle-mêle [{'label': 'POSITIVE', 'score': 0.6106797456741333}]
# Secret sur le gâteau d'anniversaire de Churchill [{'label': 'POSITIVE', 'score': 0.5976581573486328}]
# Les Communes ont réservé à Churchill un uccueil délirant [{'label': 'NEGATIVE', 'score': 0.5168910026550293}]
